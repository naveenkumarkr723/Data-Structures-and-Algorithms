# %% [markdown]
# ## Graph Deletion Methods
# ## 1. Delete by an Node/Vertex
# ![Screenshot%20%28251%29.png](attachment:Screenshot%20%28251%29.png)
# ## 2. Delete an Edge
# ![Screenshot%20%28252%29.png](attachment:Screenshot%20%28252%29.png)

# %% [markdown]
# ## Function to delete a node/vertex using adjacency matrix representation

# %%
def add_node (v) :
    global node_count
    
    
    if v in nodes :
        print(v, "is already present in the graph")

    else:
        node_count = node_count + 1
        nodes.append(v)
        for n in graph:
            n.append(0)    #### addition of a new column

        temp = []   #### addition of a new row
        for i in range(node_count) :
            temp.append(0)
        graph.append(temp)


def add_edge(v1,v2,cost):
    if v1 not in nodes:
        print(v1, "node/vertex is not present in the graph")
    elif v2 not in nodes:
        print(v2, "node/vertex is not present in the graph")
    else:
        index1 = nodes.index(v1)
        index2 = nodes.index(v2)
        
        ### setting the values for the edges which connected with each other
        graph[index1][index2] = cost
        graph[index2][index1] = cost

def delete_node(v):
    global node_count
    if v not in nodes:
        print(v, "node/vertex is not present in the graph we cannot delete the node")
    else:
        index_node = nodes.index(v)
        node_count = node_count - 1
        nodes.remove(v)
        graph.pop(index_node)
        
        for i in graph :
            i.pop(index_node)
            
        
def delete_edge(v1,v2):
    if v1 not in nodes:
        print(v1, "node/vertex is not present in the graph")
    elif v2 not in nodes:
        print(v2, "node/vertex is not present in the graph")
    else:
        index1 = nodes.index(v1)
        index2 = nodes.index(v2)
        
        ### deleting the values for the edges which connected with each other assigning the 0's to graph matrix  
        graph[index1][index2] = 0
        
        ### in directed this is not required
        graph[index2][index1] = 0

    
    
        
def print_graph():
    for i in range(node_count):
        for j in range(node_count):
            print(format(graph[i][j],'<5') ,end = ' ')
        print( )
        
        
        
nodes = []
graph = []
node_count = 0

####  Adding a new nodes
add_node("A")
add_node("B")
add_node("C")


### adding the edges for the given nodes/vetices  for the undirected unweigthed
add_edge("A","B",21)
add_edge("C","B",19)

#### deleting the node from the from graph
####delete_node("D")


print("after creating the graph is -->", graph )
print_graph()
print() 

## deleting the node from the from graph
delete_edge("A","B")


print("the graph representation  ")
print_graph()
# Out:
# after creating the graph is --> [[0, 21, 0], [21, 0, 19], [0, 19, 0]]
# 0     21    0
# 21    0     19
# 0     19    0
#
# the graph representation
# 0     0     0
# 0     0     19
# 0     19    0

# %% [markdown]
# ## function delete using the adjacency list representation
#
# ### directed and unweighted graph

# %%
def graph_list(v):
    if v in graph :
        print(v,"the given key is already present in the graph")
    else:
        graph[v] = []

def add_edge(v1,v2, cost):
    if v1 not in graph:
        print(v1, "node/vertex is not present in the graph")
    elif v2 not in graph:
        print(v2, "node/vertex is not present in the graph")
    else:
        #list1 = [v2,cost]
        #list2 = [v1,cost]
        graph[v1].append(v2)
        #graph[v2].append(list2)
        
def delete_node(v)  :
    if v not in graph :
        print(v,"the given key is already present in the graph , we cannot delete the given node/vertex")
    else:
        graph.pop(v)
        for i in graph:
            list1 = graph[i]
            if v in list1:
                list1.remove(v)
    
        
graph = {}


graph_list("A")
graph_list("B")
graph_list("C")


### adding an edge to the graph 
add_edge("A" , "B", 200)
add_edge("C" , "B", 24)
add_edge("B","A" , 55)


print(graph)

delete_node("A")


print(graph)
# Out:
# {'A': ['B'], 'B': ['A'], 'C': ['B']}
# {'B': [], 'C': ['B']}

# %% [markdown]
# ### undirected and unweighted graph

# %%
def graph_list(v):
    if v in graph :
        print(v,"the given key is already present in the graph")
    else:
        graph[v] = []

def add_edge(v1,v2, cost):
    if v1 not in graph:
        print(v1, "node/vertex is not present in the graph")
    elif v2 not in graph:
        print(v2, "node/vertex is not present in the graph")
    else:
        #list1 = [v2,cost]
        #list2 = [v1,cost]
        graph[v1].append(v2)
        graph[v2].append(v1)
        
def delete_node(v)  :
    if v not in graph :
        print(v,"the given key is already present in the graph , we cannot delete the given node/vertex")
    else:
        graph.pop(v)
        for i in graph:
            list1 = graph[i]
            if v in list1:
                list1.remove(v)
    
        
graph = {}

graph_list("A")
graph_list("B")
graph_list("C")


### adding an edge to the graph 
add_edge("A" , "B", 200)
add_edge("C" , "B", 24)
add_edge("B","A" , 55)


print(graph)

### deleting the node from the graph
delete_node("A")


print(graph)
# Out:
# {'A': ['B'], 'B': ['A', 'C'], 'C': ['B']}
# {'B': ['C'], 'C': ['B']}

# %% [markdown]
# ## undirected and weighted graph

# %%
def graph_list(v):
    if v in graph :
        print(v,"the given key is already present in the graph")
    else:
        graph[v] = []

def add_edge(v1,v2, cost):
    if v1 not in graph:
        print(v1, "node/vertex is not present in the graph")
    elif v2 not in graph:
        print(v2, "node/vertex is not present in the graph")
    else:
        list1 = [v2,cost]
        list2 = [v1,cost]
        graph[v1].append(list1)
        graph[v2].append(list2)
        
def delete_node(v)  :
    if v not in graph :
        print(v,"the given key is already present in the graph , we cannot delete the given node/vertex")
    else:
        graph.pop(v)
        for i in graph:
            list1 = graph[i]
            for j in list1:
                if v == j[0]:
                    list1.remove(j)
                    #break

        
graph = {}

graph_list("A")
graph_list("B")
graph_list("C")


### adding an edge to the graph 
add_edge("A" , "B", 200)
add_edge("C" , "B", 24)
add_edge("B","A" , 55)


print(graph)

### deleting the node from the graph
delete_node("A")

print()
print()
print("after deleting the node from the graph")
print(graph)
# Out:
# {'A': [['B', 200], ['B', 55]], 'B': [['A', 200], ['C', 24], ['A', 55]], 'C': [['B', 24]]}
#
#
# after deleting the node from the graph
# {'B': [['C', 24]], 'C': [['B', 24]]}

# %% [markdown]
# # Deleting by the Edge
#
# ### unweighted undirected graph

# %%
def graph_list(v):
    if v in graph :
        print(v,"the given key is already present in the graph")
    else:
        graph[v] = []

def add_edge(v1,v2):
    if v1 not in graph:
        print(v1, "node/vertex is not present in the graph")
    elif v2 not in graph:
        print(v2, "node/vertex is not present in the graph")
    else:
        #list1 = [v2,cost]
        #list2 = [v1,cost]
        graph[v1].append(v2)
        graph[v2].append(v1)
        
def delete_node(v)  :
    if v not in graph :
        print(v,"the given key is already present in the graph , we cannot delete the given node/vertex")
    else:
        graph.pop(v)
        for i in graph:
            list1 = graph[i]
            for j in list1:
                if v == j[0]:
                    list1.remove(j)
                    #break

                    
def delete_edge(v1,v2):
    if v1 not in graph:
        print(v1, "node/vertex is not present in the graph")
    elif v2 not in graph:
        print(v2, "node/vertex is not present in the graph")
    else:
        if v2 in graph[v1]:
            graph[v1].remove(v2)
            graph[v2].remove(v1)

        
graph = {}

graph_list("A")
graph_list("B")
graph_list("C")
graph_list("D")
graph_list("E")

### adding an edge to the graph 
add_edge("A" , "B")
add_edge("A" ,"C")
add_edge("B","E" )
add_edge("A","D" )
add_edge("B","D" )
add_edge("C","D" )
add_edge("E","D" )

print(graph)

### deleting the node from the graph
#delete_node("A")

### deleting the edge from the graph
delete_edge("C" , "D")

print()
print()
print("after deleting the node from the graph")
print(graph)
# Out:
# {'A': ['B', 'C', 'D'], 'B': ['A', 'E', 'D'], 'C': ['A', 'D'], 'D': ['A', 'B', 'C', 'E'], 'E': ['B', 'D']}
#
#
# after deleting the node from the graph
# {'A': ['B', 'C', 'D'], 'B': ['A', 'E', 'D'], 'C': ['A'], 'D': ['A', 'B', 'E'], 'E': ['B', 'D']}

# %% [markdown]
# ## Unweighted Directed Graph

# %%
def graph_list(v):
    if v in graph :
        print(v,"the given key is already present in the graph")
    else:
        graph[v] = []

def add_edge(v1,v2):
    if v1 not in graph:
        print(v1, "node/vertex is not present in the graph")
    elif v2 not in graph:
        print(v2, "node/vertex is not present in the graph")
    else:
        #list1 = [v2,cost]
        #list2 = [v1,cost]
        graph[v1].append(v2)
        # graph[v2].append(v1)
        
def delete_node(v)  :
    if v not in graph :
        print(v,"the given key is already present in the graph , we cannot delete the given node/vertex")
    else:
        graph.pop(v)
        for i in graph:
            list1 = graph[i]
            for j in list1:
                if v == j[0]:
                    list1.remove(j)
                    #break

                    
def delete_edge(v1,v2):
    if v1 not in graph:
        print(v1, "node/vertex is not present in the graph")
    elif v2 not in graph:
        print(v2, "node/vertex is not present in the graph")
    else:
        if v2 in graph[v1]:
            graph[v1].remove(v2)
            #graph[v2].remove(v1)

        
graph = {}

graph_list("A")
graph_list("B")
graph_list("C")
graph_list("D")
graph_list("E")

### adding an edge to the graph 
add_edge("A" , "B")
add_edge("A" ,"C")
add_edge("B","E" )
add_edge("A","D" )
add_edge("B","D" )
add_edge("C","D" )
add_edge("E","D" )

print(graph)

### deleting the node from the graph
#delete_node("A")

### deleting the edge from the graph
delete_edge("C" , "D")

print()
print()
print("after deleting the node from the graph")
print(graph)
# Out:
# {'A': ['B', 'C', 'D'], 'B': ['E', 'D'], 'C': ['D'], 'D': [], 'E': ['D']}
#
#
# after deleting the node from the graph
# {'A': ['B', 'C', 'D'], 'B': ['E', 'D'], 'C': [], 'D': [], 'E': ['D']}

# %% [markdown]
# ## weighted unDirected Graph

# %%
def graph_list(v):
    if v in graph :
        print(v,"the given key is already present in the graph")
    else:
        graph[v] = []

def add_edge(v1,v2,cost):
    if v1 not in graph:
        print(v1, "node/vertex is not present in the graph")
    elif v2 not in graph:
        print(v2, "node/vertex is not present in the graph")
    else:
        list1 = [v2,cost]
        list2 = [v1,cost]
        graph[v1].append(list1)
        graph[v2].append(list2)
        
def delete_node(v)  :
    if v not in graph :
        print(v,"the given key is already present in the graph , we cannot delete the given node/vertex")
    else:
        graph.pop(v)
        for i in graph:
            list1 = graph[i]
            for j in list1:
                if v == j[0]:
                    list1.remove(j)
                    #break

                    
def delete_edge(v1,v2,cost):
    if v1 not in graph:
        print(v1, "node/vertex is not present in the graph")
    elif v2 not in graph:
        print(v2, "node/vertex is not present in the graph")
    else:
        temp = [v1,cost]
        temp1 = [v2,cost]
        if temp1 in graph[v1]:
            graph[v1].remove(temp1)
            graph[v2].remove(temp)

        
graph = {}

graph_list("A")
graph_list("B")
graph_list("C")
graph_list("D")
graph_list("E")

### adding an edge to the graph 
add_edge("A" , "B",100)
add_edge("A" ,"C",4)
add_edge("B","E" ,7)
add_edge("A","D",45)
add_edge("B","D",35)
add_edge("C","D",15)
add_edge("E","D",65)

print(graph)

### deleting the node from the graph
#delete_node("A")

### deleting the edge from the graph
delete_edge("C" , "D",15)

print()
print()
print("after deleting the node from the graph")
print(graph)
# Out:
# {'A': [['B', 100], ['C', 4], ['D', 45]], 'B': [['A', 100], ['E', 7], ['D', 35]], 'C': [['A', 4], ['D', 15]], 'D': [['A', 45], ['B', 35], ['C', 15], ['E', 65]], 'E': [['B', 7], ['D', 65]]}
#
#
# after deleting the node from the graph
# {'A': [['B', 100], ['C', 4], ['D', 45]], 'B': [['A', 100], ['E', 7], ['D', 35]], 'C': [['A', 4]], 'D': [['A', 45], ['B', 35], ['E', 65]], 'E': [['B', 7], ['D', 65]]}

# %% [markdown]
# ## weighted Directed Graph

# %%
def graph_list(v):
    if v in graph :
        print(v,"the given key is already present in the graph")
    else:
        graph[v] = []

def add_edge(v1,v2,cost):
    if v1 not in graph:
        print(v1, "node/vertex is not present in the graph")
    elif v2 not in graph:
        print(v2, "node/vertex is not present in the graph")
    else:
        list1 = [v2,cost]
        #list2 = [v1,cost]
        graph[v1].append(list1)
        #graph[v2].append(list2)
        
def delete_node(v)  :
    if v not in graph :
        print(v,"the given key is already present in the graph , we cannot delete the given node/vertex")
    else:
        graph.pop(v)
        for i in graph:
            list1 = graph[i]
            for j in list1:
                if v == j[0]:
                    list1.remove(j)
                    #break

                    
def delete_edge(v1,v2,cost):
    if v1 not in graph:
        print(v1, "node/vertex is not present in the graph")
    elif v2 not in graph:
        print(v2, "node/vertex is not present in the graph")
    else:
        temp = [v1,cost]
        temp1 = [v2,cost]
        if temp1 in graph[v1]:
            graph[v1].remove(temp1)
            #graph[v2].remove(temp)

        
graph = {}

graph_list("A")
graph_list("B")
graph_list("C")
graph_list("D")
graph_list("E")

### adding an edge to the graph 
add_edge("A" , "B",100)
add_edge("A" ,"C",4)
add_edge("B","E" ,7)
add_edge("A","D",45)
add_edge("B","D",35)
add_edge("C","D",15)
add_edge("E","D",65)

print(graph)

### deleting the node from the graph
#delete_node("A")

### deleting the edge from the graph
delete_edge("C" , "D",15)

print()
print()
print("after deleting the node from the graph")
print(graph)
# Out:
# {'A': [['B', 100], ['C', 4], ['D', 45]], 'B': [['E', 7], ['D', 35]], 'C': [['D', 15]], 'D': [], 'E': [['D', 65]]}
#
#
# after deleting the node from the graph
# {'A': [['B', 100], ['C', 4], ['D', 45]], 'B': [['E', 7], ['D', 35]], 'C': [], 'D': [], 'E': [['D', 65]]}
