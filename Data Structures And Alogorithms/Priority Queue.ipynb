# %% [markdown]
# this is the improved version of the queue
# this works on the based on the priority method ex : in real life hospitals queue critical patients treat first
#
# ![Screenshot%20%28154%29.png](attachment:Screenshot%20%28154%29.png)

# %%
## lower value the high priority 

q = []
q.append(12)
q.append(9)
q.append(25)

q.sort()
q
# Out:
# [9, 12, 25]

# %%
q.pop(0)
# Out:
# 9

# %%
### the above method is not a good way of practising

### we will use binary heap methodology to perform the  Proirity Queue

import queue

priority = queue.PriorityQueue()

priority.put(10)
priority.put(6)
priority.put(20)
priority.put(0)
priority.put(56)

# %%
priority.get()
# Out:
# 0

# %%
q = []
q.append((1,"alexa"))
q.append((4,"alexi"))
q.append((3,"ale"))

q.sort(reverse = True)
q
# Out:
# [(4, 'alexi'), (3, 'ale'), (1, 'alexa')]

# %%
q.pop(0)
# Out:
# (4, 'alexi')
