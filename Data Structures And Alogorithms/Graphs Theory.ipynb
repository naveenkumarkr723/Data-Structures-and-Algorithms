# %% [markdown]
# ## A Graph
# - is a non-linear data structure consisting of nodes and edges. The nodes are sometimes also referred to as vertices and the edges are lines or arcs that connect any two nodes in the graph. More formally a Graph can be defined as,
#
# ![Screenshot%20%28219%29.png](attachment:Screenshot%20%28219%29.png)

# %% [markdown]
# In the above Graph, the set of vertices V = {A,B,C,D,E} and the set of edges E = {AB,AC,AF,BC,BD,BE,CD,CF,DE,FA,FC}.
#
# Graphs are used to solve many real-life problems. Graphs are used to represent networks. The networks may include paths in a city or telephone network or circuit network. Graphs are also used in social networks like linkedIn, Facebook. For example, in Facebook, each person is represented with a vertex(or node). Each node is a structure and contains information like person id, name, gender, locale etc.
#
# ## Real Life Examples
#
# 1. GPUS and Googel Maps
# 2. Linkedin,Facebook
# 3. e - commerce websites
# 4. In computer Science graphs are used to flow of Computation
#
# ### Maps and Routes
#
# ![Screenshot%20%28221%29.png](attachment:Screenshot%20%28221%29.png)
#
# ### Friend Circle
#
# ![Screenshot%20%28222%29.png](attachment:Screenshot%20%28222%29.png)
#
# ### E - Commerce
# ![Screenshot%20%28223%29.png](attachment:Screenshot%20%28223%29.png)

# %% [markdown]
# ###  1. directed graph
#
# ###  2. undirected graph
#
# ![Screenshot%20%28226%29.png](attachment:Screenshot%20%28226%29.png)

# %% [markdown]
# ### Weighted Graph
#
# ###  UnWeighted Graph
#
# if edges have any weights that is known as Weighted Graph
#
# ![Screenshot%20%28228%29.png](attachment:Screenshot%20%28228%29.png)

# %% [markdown]
# #### Cyclic Graph
#
# #### Acyclic Graph
#
# if a graph traverse from one node/vertex to another node and completes at the rotation at the same node/vertex is known as cyclic graph , Trees are not the cyclic graphs
#
# ![Screenshot%20%28230%29.png](attachment:Screenshot%20%28230%29.png)

# %% [markdown]
# ### Graph is a non - linear Data Structure consisting of node/vertex and edges
#
# ![Screenshot%20%28231%29.png](attachment:Screenshot%20%28231%29.png)
#
# in directed graphs A--->B  A is adjacent to B , B is adjacent from A
#
#
# ## Path
# ![Screenshot%20%28232%29.png](attachment:Screenshot%20%28232%29.png)
#
# ![Screenshot%20%28233%29.png](attachment:Screenshot%20%28233%29.png)
#
# Length of Path is number of edges present from the first node to last node
# Length of Path must be greater than or equal to 1 always
