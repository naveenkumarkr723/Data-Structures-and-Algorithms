# %%
## Linked List 
## it is a dynamic data structure



There are three types of the linkedlists they are the 
1. singly
2. doubly
3. circular

Sinly Linked List operations are :
    add
    remove or delete
    
    
### Traversal :

### Traversal Operation :

condition for traversal LL:
    1. is LL is empty or not
         when the LL is empty then we have the head is None
    2. if LL is not empty 

    Start with the head of the Linked List,

    Access the data if head is not NULL

    Goto Next Node Access Node data

    Continue untill last node

# %%
## Traversal method of the LinkedList

class Node:

    def __init__(self, data):
        self.data = data
        self.ref = None


class LinkedList:
    
    def __init__(self):
        self.head = None

    def print_LL (self):
        if self.head is None:
            print("Linked-List is empty!")
        else:
            n = self.head
            while n is not None: 
                print (n.data)
                n = n.ref
                
        
LL1 = LinkedList ()

LL1.print_LL()
# Out:
# Linked-List is empty!

# %%
### Adding in the Beginning

class Node:

    def __init__(self, data):
        self.data = data
        self.ref = None


class LinkedList:
    
    def __init__(self):
        self.head = None
        
    ### TRAVERSAL FUNCTION
    def print_LL (self):
        if self.head is None:
            print("inked list is empty!")
        else:
            n = self.head
            while n is not None: 
                print ("the value of the  node : " ,n.data)
                n = n.ref
                print("the reference value of the next node : ",n)
                
                
    def add_begin(self, data):
        new_node     = Node(data)
        new_node.ref = self.head
        self.head    = new_node
    
    
    
LL1 = LinkedList()

### adding the new element before the element in the linked list
LL1.add_begin(10)

## see the 200 will print first than the 10
LL1.add_begin(200)
LL1.print_LL()
# Out:
# the value of the  element :  200
# the reference value of the next element :  <__main__.Node object at 0x000001EB88535708>
# the value of the  element :  10
# the reference value of the next element :  None

# %%
class Node:

    def __init__(self, data):
        self.data = data
        self.ref = None


class LinkedList:
    
    def __init__(self):
        self.head = None

    def print_LL (self):
        if self.head is None:
            print("inked list is empty!")
        else:
            n = self.head
            while n is not None: 
                print ("the value of the  element : " ,n.data)
                n = n.ref
                print("the reference value of the next element : ",n)
                
                
    def add_begin(self, data):
        new_node     = Node(data)
        new_node.ref = self.head
        self.head    = new_node
        
    def add_end(self, data):
        new_node = Node(data)
        
        if self.head is None:
            self.head = new_node
        else:
            n  = self.head
            while n.ref is not None:
                n =  n.ref
            n.ref = new_node
            
            
LL1 = LinkedList()

### adding the new element before the element in the linked list
LL1.add_begin(10)


### adding the new element at last  in the linked list
LL1.add_end(100)


## see the 200 will print first than the 10
LL1.add_begin(200)
LL1.print_LL()
# Out:
# the value of the  element :  200
# the reference value of the next element :  <__main__.Node object at 0x000001EB88430A08>
# the value of the  element :  10
# the reference value of the next element :  <__main__.Node object at 0x000001EB8851C508>
# the value of the  element :  100
# the reference value of the next element :  None

# %%
class Node:

    def __init__(self, data):
        self.data = data
        self.ref = None


class LinkedList:
    
    def __init__(self):
        self.head = None

    def print_LL (self):
        if self.head is None:
            print("inked list is empty!")
        else:
            n = self.head
            while n is not None: 
                print ("the value of the  element : " ,n.data)
                n = n.ref
                print("the reference value of the next element : ",n)
                
                
    def add_begin(self, data):
        new_node     = Node(data)
        new_node.ref = self.head
        self.head    = new_node
        
    def add_end(self, data):
        new_node = Node(data)
        
        if self.head is None:
            self.head = new_node
        else:
            n  = self.head
            while n.ref is not None:
                n =  n.ref
            n.ref = new_node
            
    def add_after(self, data,x): 
        n = self.head
        while n is not None:
            if n.data == x :
                break
            n = n.ref    
        
        if n is None:
            print("node is not present LinkedList")      
        else:
            new_node = Node(data) 
            new_node.ref = n.ref
            n.ref = new_node
        

LL1 = LinkedList()

### adding the new element before the element in the linked list
LL1.add_begin(10)


### adding the new element at last  in the linked list
LL1.add_end(100)


### adding the node in between we use the adding the node after the given node
LL1.add_after(500,10)


## see the 200 will print first than the 10
LL1.add_begin(200)

LL1.print_LL()
# Out:
# the value of the  element :  200
# the reference value of the next element :  <__main__.Node object at 0x0000024C90B65CC8>
# the value of the  element :  10
# the reference value of the next element :  <__main__.Node object at 0x0000024C90B83C48>
# the value of the  element :  500
# the reference value of the next element :  <__main__.Node object at 0x0000024C90B835C8>
# the value of the  element :  100
# the reference value of the next element :  None

# %%
class Node:

    def __init__(self, data):
        self.data = data
        self.ref = None


class LinkedList:
    
    def __init__(self):
        self.head = None

    def print_LL (self):
        if self.head is None:
            print("inked list is empty!")
        else:
            n = self.head
            while n is not None: 
                print ("the value of the  element : " ,n.data)
                n = n.ref
                print("the reference value of the next element : ",n)
                
                
    def add_begin(self, data):
        new_node     = Node(data)
        new_node.ref = self.head
        self.head    = new_node
        
    def add_end(self, data):
        new_node = Node(data)
        
        if self.head is None:
            self.head = new_node
        else:
            n  = self.head
            while n.ref is not None:
                n =  n.ref
            n.ref = new_node
            
    def add_after(self, data,x): 
        n = self.head
        while n is not None:
            if n.data == x :
                break
            n = n.ref    
        
        if n is None:
            print("node is not present add_after LinkedList")      
        else:
            new_node = Node(data) 
            new_node.ref = n.ref
            n.ref = new_node
    
    
    def add_before(self, data,x): 
        
        ### adding the element at before first node
        if self.head.data is None:
            print("node is not present add_before LinkedList") 
            return
        if self.head.data ==x:
            new_node     = Node(data)
            new_node.ref = self.head
            self.head    = new_node
            return
        
        ### adding the node before the any given node not first node
        n = self.head
        while n.ref is not None:
            if n.ref.data == x :
                break
            n = n.ref   
        if n.ref is None:
            print("node is not present add_before LinkedList")      
        else:
            new_node = Node(data) 
            new_node.ref = n.ref
            n.ref = new_node

    def insert_empty(self,data):
        if self.head is None:
            new_node = Node(data)
            self.head = new_node
        else:
            print("Linked List is not empty")
            
            
    def delete_first(self):
        if self.head is None:
            print("it is given linked list is not found in delete_first method")
        else:
            self.head = self.head.ref
        
    def delete_last(self):
        if self.head is None:
            print("it is given linked list is not found in delete_last method")
            
        elif self.head.ref is None:
            self.head = None
        else:
            n = self.head
            while n.ref.ref is not None :
                n = n.ref
            n.ref = None
            
            
    def delete_by_value(self,x):
        if self.head is None:
            print("it is given linked list is not found in delete_last method")
            return
        if x == self.head.data:
            self.head = self.head.ref
            return
        n = self.head 
        while n.ref is not None:
            if n.ref.data == x :
                break
            n = n.ref
                  
        if n.ref is None:
            print("the node is not present in the delete_by_value ")
        else:
            n.ref = n.ref.ref

            
            
            
            
LL1 = LinkedList()

LL1.add_begin(40)
LL1.add_begin(50)
LL1.add_begin(30)
LL1.add_begin(80)

LL1.delete_by_value(50)

### it is deleted the first element  
#LL1.delete_first()
#LL1.delete_last()
LL1.print_LL()
# Out:
# the value of the  element :  80
# the reference value of the next element :  <__main__.Node object at 0x0000024C90C41D08>
# the value of the  element :  30
# the reference value of the next element :  <__main__.Node object at 0x0000024C90C41D48>
# the value of the  element :  40
# the reference value of the next element :  None

# %%
LL1 = LinkedList()
### adding the new element before the element in the linked list
LL1.add_begin(10)


### adding the new element at last  in the linked list
LL1.add_end(100)


### adding the node in between we use the adding the node after the given node
LL1.add_after(500,10)

LL1.add_before(555,10)

## see the 200 will print first than the 10
LL1.add_begin(200)


LL1.insert_empty(1000)
LL1.insert_empty(2000)


LL1.print_LL()
# Out:
# node is not present add_after LinkedList

# %%
class Node:

    def __init__(self, data):
        self.data = data
        self.ref = None


class LinkedList:
    
    def __init__(self):
        self.head = None

    def print_LL (self):
        if self.head is None:
            print("inked list is empty!")
        else:
            n = self.head
            while n is not None: 
                print ("the value of the  element : " ,n.data)
                n = n.ref
                print("the reference value of the next element : ",n)
                
                
    def add_begin(self, data):
        new_node     = Node(data)
        new_node.ref = self.head
        self.head    = new_node
        
    def add_end(self, data):
        new_node = Node(data)
        
        if self.head is None:
            self.head = new_node
        else:
            n  = self.head
            while n.ref is not None:
                n =  n.ref
            n.ref = new_node
            
    def add_after(self, data,x): 
        n = self.head
        while n is not None:
            if n.data == x :
                break
            n = n.ref    
        
        if n is None:
            print("node is not present add_after LinkedList")      
        else:
            new_node = Node(data) 
            new_node.ref = n.ref
            n.ref = new_node
    
    
    def add_before(self, data,x): 
        ### adding the element at before first node
        if self.head.data is None:
            print("node is not present add_before LinkedList") 
            return
        if self.head.data ==x:
            new_node     = Node(data)
            new_node.ref = self.head
            self.head    = new_node
            return
        
        ### adding the node before the any given node not first node
        n = self.head
        while n.ref is not None:
            if n.ref.data == x :
                break
            n = n.ref   
        if n.ref is None:
            print("node is not present add_before LinkedList")      
        else:
            new_node = Node(data) 
            new_node.ref = n.ref
            n.ref = new_node

    def insert_empty(self,data):
        if self.head is None:
            new_node = Node(data)
            self.head = new_node
        else:
            print("Linked List is not empty")
            
            
LL1 = LinkedList()

### adding the new element before the element in the linked list
LL1.add_begin(10)


### adding the new element at last  in the linked list
LL1.add_end(100)


### adding the node in between we use the adding the node after the given node
LL1.add_after(200,1000)


## see the 200 will print first than the 10
LL1.add_begin(200)

LL1.print_LL()


### in this example we are not giving the correct node where we have add the node so it just simply skip that part 
### in this i have 1000 which is actually not presented in the code it is just skip it
# Out:
# node is not present add_after LinkedList
# the value of the  element :  200
# the reference value of the next element :  <__main__.Node object at 0x0000024C90C13D88>
# the value of the  element :  10
# the reference value of the next element :  <__main__.Node object at 0x0000024C90B68788>
# the value of the  element :  100
# the reference value of the next element :  None
